# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

import scipy.stats as stats

import dataframe_image as dfi

# %%
df = pd.read_csv("../../../Data/CleanData_mileage_price_enginesize.csv")

df.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  Aygo  2017   9250       Manual     4414    Other  150  68.9         1.0
# 1  Aygo  2017   7100       Manual    32351   Petrol    0  68.9         1.0
# 2  Aygo  2016   6500       Manual    26193   Petrol    0  69.0         1.0
# 3  Aygo  2017   7650       Manual    12134   Petrol    0  68.9         1.0
# 4  Aygo  2016   6999       Manual    21123   Petrol    0  69.0         1.0

# %%
mask = df["model"] == "Focus"
df2 = df.loc[mask,:]
focusModel = df2

mask = df["model"] == "Fiesta"
df3 = df.loc[mask,:]
fiestaModel = df3

# %%
fiesta = sns.scatterplot(data=fiestaModel, x = "year", y="price", color = "#2A6BAC")
focus = sns.scatterplot(data= focusModel, x = "year", y="price", color = "#C6C6C6", legend = True)
fiesta.axes.set_title("Ford Focus vs Ford Fiesta", font = "Arial", fontsize = 28, color = "#000000")
fiesta.set_ylabel("Sales Price (Euros)", font = "Arial", fontsize = 12, color = "#000000")
fiesta.set_xlabel("Model Years", font = "Arial", fontsize = 12, color = "#000000")
fiesta.legend(labels = ["Fiesta","Ford"], fontsize = 14)
plt.gcf().set_size_inches(12,10)
plt.savefig("out2.png")
plt.show()
